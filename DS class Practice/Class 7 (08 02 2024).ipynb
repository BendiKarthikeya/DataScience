# %%
import pandas as pd

# %%
kar=pd.read_csv("machine.csv.csv")

# %%
kar
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
kar.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
kar.tail()
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 22184          0  Business Data Collection - BDC
# 22185          0  Business Data Collection - BDC
# 22186          0  Business Data Collection - BDC
# 22187          0  Business Data Collection - BDC
# 22188          0  Business Data Collection - BDC
#
#                                               Group  \
# 22184  Territorial authority by employment variable
# 22185  Territorial authority by employment variable
# 22186  Territorial authority by employment variable
# ...

# %%
kar.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4      float64
# Series_title_5      float64
# dtype: object

# %%
kar.STATUS
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        F
#         ..
# 22184    C
# 22185    C
# 22186    C
# 22187    C
# 22188    C
# Name: STATUS, Length: 22189, dtype: object

# %%
kar["STATUS"]
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        F
#         ..
# 22184    C
# 22185    C
# 22186    C
# 22187    C
# 22188    C
# Name: STATUS, Length: 22189, dtype: object

# %%
kar.STATUS.describe()
# Out:
# count     22189
# unique        3
# top           F
# freq      12776
# Name: STATUS, dtype: object

# %%
kar.STATUS.value_counts()
# Out:
# STATUS
# F    12776
# R     7902
# C     1511
# Name: count, dtype: int64

# %%
kar.STATUS.value_counts().sum()
# Out:
# 22189

# %%
kar.shape
# Out:
# (22189, 14)

# %%
kar.STATUS.value_counts(normalize=True)
# Out:
# STATUS
# F    0.575781
# R    0.356122
# C    0.068097
# Name: proportion, dtype: float64

# %%
type(kar.STATUS.value_counts())
# Out:
# pandas.core.series.Series

# %%
# create a sample dataset
df = pd.DataFrame({
    'gender': ['male', 'male', 'female', 'female', 'male', 'female', 'male', 'female'],
    'education_level': ['high school', 'college', 'college', 'graduate', 'high school', 'graduate', 'college', 'graduate'],
    'score': [75, 82, 88, 95, 69, 92, 78, 85]
})

# create a crosstab table of gender and education level

# %%
ct = pd.crosstab(df['gender'], df['education_level'])
print(ct)
# Out:
# education_level  college  graduate  high school
# gender
# female                 1         3            0
# male                   2         0            2

# %%
kar.loc[[1]]
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 1  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
#
#    Series_title_4  Series_title_5
# 1             NaN             NaN

# %%
kar
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
kar.loc[[22188],["Series_reference"]]
# Out:
#       Series_reference
# 22188    BDCQ.SEE3999A

# %%
kar.loc[[1,10],["Series_title_1"]]
# Out:
#    Series_title_1
# 1     Filled jobs
# 10    Filled jobs

# %%
kar.loc[:,"Series_title_1"]
# Out:
# 0                                   Filled jobs
# 1                                   Filled jobs
# 2                                   Filled jobs
# 3                                   Filled jobs
# 4                                   Filled jobs
#                           ...
# 22184    Filled jobs (workplace location based)
# 22185    Filled jobs (workplace location based)
# 22186    Filled jobs (workplace location based)
# 22187    Filled jobs (workplace location based)
# 22188    Filled jobs (workplace location based)
# Name: Series_title_1, Length: 22189, dtype: object

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "gender":["M","M","M","M","F","F","F"]}

# %%
data
# Out:
# {'name': ['Bill', 'Tom', 'Tim', 'John', 'Alex', 'Vanessa', 'Kate'],
#  'score': [90, 80, 85, 75, 95, 60, 65],
#  'sport': ['Wrestling',
#   'Football',
#   'Skiing',
#   'Swimming',
#   'Tennis',
#   'Karete',
#   'Surfing'],
#  'gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
df=pd.DataFrame(data,columns=["name","sport","score","gender"])

# %%
df
# Out:
#       name      sport  score gender
# 0     Bill  Wrestling     90      M
# 1      Tom   Football     80      M
# 2      Tim     Skiing     85      M
# 3     John   Swimming     75      M
# 4     Alex     Tennis     95      F
# 5  Vanessa     Karete     60      F
# 6     Kate    Surfing     65      F

# %%
df.head()
# Out:
#    name      sport  score gender
# 0  Bill  Wrestling     90      M
# 1   Tom   Football     80      M
# 2   Tim     Skiing     85      M
# 3  John   Swimming     75      M
# 4  Alex     Tennis     95      F

# %%
df.tail(3)
# Out:
#       name    sport  score gender
# 4     Alex   Tennis     95      F
# 5  Vanessa   Karete     60      F
# 6     Kate  Surfing     65      F

# %%
df.head(2)
# Out:
#    name      sport  score gender
# 0  Bill  Wrestling     90      M
# 1   Tom   Football     80      M

# %%
df=pd.DataFrame(data,columns=["name","sport","score","gender","age"])
df
# Out:
#       name      sport  score gender  age
# 0     Bill  Wrestling     90      M  NaN
# 1      Tom   Football     80      M  NaN
# 2      Tim     Skiing     85      M  NaN
# 3     John   Swimming     75      M  NaN
# 4     Alex     Tennis     95      F  NaN
# 5  Vanessa     Karete     60      F  NaN
# 6     Kate    Surfing     65      F  NaN

# %%
df["sport"]
# Out:
# 0    Wrestling
# 1     Football
# 2       Skiing
# 3     Swimming
# 4       Tennis
# 5       Karete
# 6      Surfing
# Name: sport, dtype: object

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"],
                index=["one","two","three","four","five","six","seven"])
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90  NaN
# two        Tom   Football      M     80  NaN
# three      Tim     Skiing      M     85  NaN
# four      John   Swimming      M     75  NaN
# five      Alex     Tennis      F     95  NaN
# six    Vanessa     Karete      F     60  NaN
# seven     Kate    Surfing      F     65  NaN

# %%
df["name"]
# Out:
# one         Bill
# two          Tom
# three        Tim
# four        John
# five        Alex
# six      Vanessa
# seven       Kate
# Name: name, dtype: object

# %%
my_columns=["name","sport"]
df[my_columns]
# Out:
#           name      sport
# one       Bill  Wrestling
# two        Tom   Football
# three      Tim     Skiing
# four      John   Swimming
# five      Alex     Tennis
# six    Vanessa     Karete
# seven     Kate    Surfing
